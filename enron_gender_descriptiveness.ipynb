# %%
import nltk
import pandas as pd
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')
enron_emails = pd.read_csv('clean_enron_emails.csv')
enron_emails = enron_emails.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1', 'text_tokens'])
enron_emails['clean_text'] = [row.lower() for row in enron_emails['clean_text']]
stop_words = set(stopwords.words('english'))
enron_emails['text_tokens'] = [nltk.word_tokenize(text) for text in enron_emails['clean_text']]
enron_emails['text_no_stop'] = [[w for w in word_tokens if not w in stop_words] for word_tokens in enron_emails['text_tokens']]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\manjo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\manjo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
nltk.download('averaged_perceptron_tagger')
enron_emails['text_ns_pos'] = [nltk.pos_tag(text) for text in enron_emails['text_no_stop']]
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\manjo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.

# %%
from nltk.chunk import ne_chunk
nltk.download('maxent_ne_chunker')
nltk.download('words')
enron_emails['text_named_entities'] = [ne_chunk(text, binary=True) for text in enron_emails['text_ns_pos']]
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\manjo\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\manjo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.

# %%
enron_female_sender = enron_emails[enron_emails['sender_gender'] =='female'].reset_index()
enron_male_sender = enron_emails[enron_emails['sender_gender'] =='male'].reset_index()
enron_andy_sender = enron_emails[enron_emails['sender_gender'] =='andy'].reset_index()

# %%
enron_female_sender.head()
# Out:
#    index                       date                      sender  \
# 0    347  2000-12-13 08:01:00-08:00  rebecca.cantrell@enron.com
# 1    407  2000-12-13 05:26:00-08:00  stephanie.miller@enron.com
# 2    474  2000-12-12 04:41:00-08:00   christi.nicolay@enron.com
# 3    506  2000-12-07 01:55:00-08:00    tiffany.miller@enron.com
# 4    679  2000-12-07 01:55:00-08:00    tiffany.miller@enron.com
#
#                 recipient1                                            subject  \
# 0  phillip.allen@enron.com                                                Re:
# 1  jeff.dasovich@enron.com  Re: Enron Response to San Diego Request for Ga...
# 2  phillip.allen@enron.com     Re: Talking points about California Gas market
# 3  phillip.allen@enron.com                                 System Development
# 4  phillip.allen@enron.com                                 System Development
#
#                                                 text sender_name  \
# ...

# %%
enron_female_sender['text_ns_pos'][0]
# Out:
# [('phillip', 'NN'),
#  ('value', 'NN'),
#  ('axis', 'JJ'),
#  ('sheet', 'NN'),
#  ('2', 'CD'),
#  ('socalprices', 'NNS'),
#  ('spread', 'JJ'),
#  ('sheet', 'NN'),
#  ('supposed', 'VBN'),
#  ('?', '.'),
#  ('right', 'JJ'),
#  ('values', 'NNS'),
#  ('millions', 'NNS'),
#  ('?', '.'),
#  ('come', 'VB'),
#  ('?', '.'),
#  ('cant', 'JJ'),
#  ('relate', 'NN'),
#  ('sheet', 'NN'),
#  ('1', 'CD'),
#  ('spread', 'JJ'),
#  ('sheet', 'NN'),
#  ('.', '.'),
#  ('told', 'VBD'),
#  ('mike', 'NN'),
#  ('file', 'NN'),
#  ('outoftime', 'NN'),
#  ('tomorrow', 'NN'),
#  ('supplement', 'NN'),
#  ('comments', 'NNS'),
#  ('today', 'NN'),
#  ('along', 'IN'),
#  ('cover', 'JJ'),
#  ('letter', 'NN'),
#  ('.', '.'),
#  ('fully', 'RB'),
#  ('understand', 'JJ'),
#  ('charts', 'NNS'),
#  ('constructed', 'VBD'),
#  ('ran', 'JJ'),
#  ('time', 'NN'),
#  ('today', 'NN'),
#  ('.', '.'),
#  ('much', 'JJ'),
#  ('better', 'JJR'),
#  ('file', 'NN'),
#  ('outoftime', 'JJ'),
#  ('supplement', 'NN'),
#  ('timely', 'JJ'),
# ...

# %%
femaleAvgAdjPerEmail = 0
totalAdjInEmail = 0
for emailIndex,pairsList in enumerate(enron_female_sender['text_ns_pos']):
    for pairsIndex,pairs in enumerate(pairsList):
        wordType = pairs[1]
        if wordType == 'JJ':
            totalAdjInEmail = totalAdjInEmail + 1
        elif wordType == "JJR":
            totalAdjInEmail = totalAdjInEmail + 1
        elif wordType == "JJS":
            totalAdjInEmail = totalAdjInEmail + 1
    if emailIndex != 0:
        femaleAvgAdjPerEmail = totalAdjInEmail / emailIndex
print(femaleAvgAdjPerEmail)
# Out:
# 23.080737165423432

# %%
maleAvgAdjPerEmail = 0
totalAdjInEmail = 0
for emailIndex,pairsList in enumerate(enron_male_sender['text_ns_pos']):
    for pairsIndex,pairs in enumerate(pairsList):
        wordType = pairs[1]
        if wordType == 'JJ':
            totalAdjInEmail = totalAdjInEmail + 1
        elif wordType == "JJR":
            totalAdjInEmail = totalAdjInEmail + 1
        elif wordType == "JJS":
            totalAdjInEmail = totalAdjInEmail + 1
    if emailIndex != 0:
        maleAvgAdjPerEmail = totalAdjInEmail / emailIndex
print(maleAvgAdjPerEmail)
# Out:
# 18.551507897270433

# %%
femaleAvgAdjPerEmail = 0
totalAdjInEmail = 0
df['something'] = 
for emailIndex,pairsList in enumerate(enron_female_sender['text_ns_pos']):
    adjInEmail = 0
    for pairsIndex,pairs in enumerate(pairsList):
        wordType = pairs[1]
        if wordType == 'JJ':
            totalAdjInEmail = totalAdjInEmail + 1
            adjInEmail = adjInEmail + 1
        elif wordType == "JJR":
            totalAdjInEmail = totalAdjInEmail + 1
            adjInEmail = adjInEmail + 1
        elif wordType == "JJS":
            totalAdjInEmail = totalAdjInEmail + 1
            adjInEmail = adjInEmail + 1
        print("Adjectives in email: " + str(adjInEmail))
    if emailIndex != 0:
        femaleAvgAdjPerEmail = totalAdjInEmail / emailIndex
print(femaleAvgAdjPerEmail)
# Out:
# Adjectives in email: 0
# Adjectives in email: 0
# Adjectives in email: 1
# Adjectives in email: 1
# Adjectives in email: 1
# Adjectives in email: 1
# Adjectives in email: 2
# Adjectives in email: 2
# Adjectives in email: 2
# Adjectives in email: 2
# Adjectives in email: 3
# Adjectives in email: 3
# Adjectives in email: 3
# Adjectives in email: 3
# Adjectives in email: 3
# Adjectives in email: 3
# Adjectives in email: 4
# Adjectives in email: 4
# Adjectives in email: 4
# Adjectives in email: 4
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 5
# Adjectives in email: 6
# Adjectives in email: 6
# Adjectives in email: 6
# Adjectives in email: 6
# Adjectives in email: 7
# Adjectives in email: 7
# Adjectives in email: 7
# Adjectives in email: 8
# ...

# %%
def AdjInEmail(pairsList):
    #print(pairsList)
    adjInEmail = 0
    for index,pairs in enumerate(pairsList):
       # print(pairs)
        wordType = pairs[1]
        if wordType == 'JJ':
            adjInEmail = adjInEmail + 1
        elif wordType == "JJR":
            adjInEmail = adjInEmail + 1
        elif wordType == "JJS":
            adjInEmail = adjInEmail + 1
    return adjInEmail

enron_female_sender['adjInEmail'] = [AdjInEmail(pairsList) for pairsList in enron_female_sender['text_ns_pos']]
enron_male_sender['adjInEmail'] = [AdjInEmail(pairsList) for pairsList in enron_male_sender['text_ns_pos']]
